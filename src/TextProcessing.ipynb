# %%
import nltk
from nltk.tokenize import regexp_tokenize, wordpunct_tokenize, blankline_tokenize
import pandas as pd
import os
import pillow
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-7fde2e41869c> in <module>
#       3 import pandas as pd
#       4 import os
# ----> 5 import pillow
#
# ModuleNotFoundError: No module named 'pillow'

# %%
Data = pd.read_csv('../data/Lyrics.csv')
Data.columns
# Out:
# Index(['annotation_count', 'api_path', 'full_title',
#        'header_image_thumbnail_url', 'header_image_url', 'id',
#        'lyrics_owner_id', 'lyrics_state', 'path', 'primary_artist',
#        'pyongs_count', 'song_art_image_thumbnail_url', 'stats', 'title',
#        'title_with_featured', 'url', 'Lyrics', 'concurrents', 'hot',
#        'pageviews', 'unreviewed_annotations', 'api_path.1',
#        'header_image_url.1', 'id.1', 'image_url', 'iq', 'is_meme_verified',
#        'is_verified', 'name', 'url.1'],
#       dtype='object')

# %% [markdown]
# #Load the data

# %%
Data = Data[['full_title','Lyrics','pageviews','id']]
Data
# Out:
#                                           full_title  \
# 0                    Nikes by Frank Ocean (Ft. KOHH)
# 1                       12/12 Songs by Brock Chenier
# 2  Die Lieblingsopener der Community by Genius De...
# 3                           SOTY List - 2016 by Drxw
# 4               Nikes (Video Version) by Frank Ocean
# 5   The 50 Best Songs of 2016 Ranking Page by Genius
# 6  ​blonded RADIO Episode 6 Tracklist by Frank Ocean
# 7  My Top Albums & Songs of 2016 by Brendan Frede...
# 8         The Best Music Videos of 2016 by Pitchfork
#
#                                               Lyrics  pageviews         id
# 0  [Verse 1: Frank Ocean]\r\nThese bitches want N...  1405145.0  2841610.0
# 1  AAlex Turner - "Stuck on the Puzzle"\r\nAllan ...        NaN  2959888.0
# 2  Bitte wirklich nur 10 Tracks auswählen. Danke!...        NaN  2958910.0
# 3  *Will be edited soon*\r\n\r\nSongs:\r\n1. Nike...        NaN  2949742.0
# ...

# %%
# Out:
#                                           full_title  \
# 0                    Nikes by Frank Ocean (Ft. KOHH)
# 1                       12/12 Songs by Brock Chenier
# 2  Die Lieblingsopener der Community by Genius De...
# 3                           SOTY List - 2016 by Drxw
# 4               Nikes (Video Version) by Frank Ocean
# 5   The 50 Best Songs of 2016 Ranking Page by Genius
# 6  ​blonded RADIO Episode 6 Tracklist by Frank Ocean
# 7  My Top Albums & Songs of 2016 by Brendan Frede...
# 8         The Best Music Videos of 2016 by Pitchfork
#
#                                               Lyrics
# 0  [Verse 1: Frank Ocean]\r\nThese bitches want N...
# 1  AAlex Turner - "Stuck on the Puzzle"\r\nAllan ...
# 2  Bitte wirklich nur 10 Tracks auswählen. Danke!...
# 3  *Will be edited soon*\r\n\r\nSongs:\r\n1. Nike...
# 4  [Intro]\r\nSpecial shoutout to the icon dynast...
# 5  Please do not edit the lyrics of this page. If...
# 6  Burial - Come Down To Us\r\nInterlude - ?\r\nH...
# ...
